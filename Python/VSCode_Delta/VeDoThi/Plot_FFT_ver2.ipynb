# %% [markdown]
# Đọc dữ liệu

# %%
import matplotlib.pyplot as plt
import gspread

plt.rcParams["savefig.directory"] = "A:/Ảnh đồ thị/"

#print("Dữ liệu rung Delta lần: ")
#text = input()

sa = gspread.service_account(filename="A:\Code\Google_sheet\healthy-feat-390910-729c14c55127.json")
sh = sa.open("Dữ liệu rung Delta lần 20.1") # tên sheet muốn sử dụng, đổi mỗi lần muốn đọc dữ liệu ở sheet khác
#sh = sa.open("Dữ liệu rung Delta lần " + text) # tên sheet muốn sử dụng, đổi mỗi lần muốn đọc dữ liệu ở sheet khác

wks = sh.worksheet("2. Động cơ quay với vi bước 1/32 - ko lọc") # tên worksheet muốn sử dụng, cái này mặc định rồi đừng có mà đổi

data = wks.get('L3:U')

t = []

x1 = []
y1 = []
z1 = []

x2 = []
y2 = []
z2 = []

x3 = []
y3 = []
z3 = []

# Number of sample points
N = len(data)

for i in range(0, N):
    t.append(float(data[i][0]))

    x1.append(float(data[i][1]))
    y1.append(float(data[i][2]))
    z1.append(float(data[i][3]))

    x2.append(float(data[i][4]))
    y2.append(float(data[i][5]))
    z2.append(float(data[i][6]))

    x3.append(float(data[i][7]))
    y3.append(float(data[i][8]))
    z3.append(float(data[i][9]))

# %% [markdown]
# Cài đặt thông số

# %%
linewidth = 2
fontsize = 28

x_min = 0
x_max = 10
y_min = 0
y_max = 3
# Out:
# 0.2956376039

# %%
points = []

points.append([max(x1), t[x1.index(max(x1))]])
x1.remove(max(x1))
points.append([max(x1), t[x1.index(max(x1))]])
x1.remove(max(x1))
points.append([max(x1), t[x1.index(max(x1))]])
x1.remove(max(x1))
points.append([max(x1), t[x1.index(max(x1))]])
x1.remove(max(x1))

print(points)
# Out:
# [[0.3733295143, 74.27813284], [0.3450023749, 74.20541808], [0.340518787, 74.20541808], [0.3285190989, 7.671407748]]

# %% [markdown]
# Plot Full1

# %%
fig1 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x1, label="x_1", color="blue", linewidth=linewidth, linestyle="dashed")
plt.plot(t, y1, label="y_1", color="red", linewidth=linewidth, linestyle="dashed")
plt.plot(t, z1, label="z_1", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.title("Kết quả biến đổi Fourier tín hiệu cảm biến số 1", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figure.png")
# plt.close(fig)

# %% [markdown]
# Plot X1

# %%
figX1 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x1, label="x_1", color="blue", linewidth=linewidth, linestyle="dashed")

plt.title("Kết quả biến đổi Fourier tín hiệu trục X cảm biến số 1", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureX1.png")
# plt.close(figX1)

# %% [markdown]
# Plot Y1

# %%
figY1 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, y1, label="y_1", color="red", linewidth=linewidth, linestyle="dashed")

plt.title("Kết quả biến đổi Fourier tín hiệu trục Y cảm biến số 1", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureY1.png")
# plt.close(figY1)

# %% [markdown]
# Plot Z1

# %%
figZ1 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, z1, label="z_1", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.title("Kết quả biến đổi Fourier tín hiệu trục Z cảm biến số 1", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureZ1.png")
# plt.close(figZ1)

# %% [markdown]
# Plot Full2

# %%
fig2 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x2, label="x_2", color="blue", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, y2, label="y_2", color="red", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, z2, label="z_2", color="#00aa00ff", linewidth=linewidth, linestyle="dashdot")

plt.title("Kết quả biến đổi Fourier tín hiệu cảm biến số 2", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figure.png")
# plt.close(fig)

# %% [markdown]
# Plot X2

# %%
figX2 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x2, label="x_2", color="blue", linewidth=linewidth, linestyle="dashdot")

plt.title("Kết quả biến đổi Fourier tín hiệu trục X cảm biến số 2", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureX1.png")
# plt.close(figX1)

# %% [markdown]
# Plot Y2

# %%
figY2 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, y2, label="y_2", color="red", linewidth=linewidth, linestyle="dashdot")

plt.title("Kết quả biến đổi Fourier tín hiệu trục Y cảm biến số 2", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureY1.png")
# plt.close(figY1)

# %% [markdown]
# Plot Z2

# %%
figZ2 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, z2, label="z_2", color="#00aa00ff", linewidth=linewidth, linestyle="dashdot")

plt.title("Kết quả biến đổi Fourier tín hiệu trục Z cảm biến số 2", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureZ1.png")
# plt.close(figZ1)

# %% [markdown]
# Plot Full3

# %%
fig3 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x3, label="x_3", color="blue", linewidth=linewidth, linestyle="solid")
plt.plot(t, y3, label="y_3", color="red", linewidth=linewidth, linestyle="solid")
plt.plot(t, z3, label="z_3", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("Kết quả biến đổi Fourier tín hiệu cảm biến số 3", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figure.png")
# plt.close(fig3)

# %% [markdown]
# Plot X3

# %%
figX3 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x3, label="x_3", color="blue", linewidth=linewidth, linestyle="solid")

plt.title("Kết quả biến đổi Fourier tín hiệu trục X cảm biến số 3", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureX1.png")
# plt.close(figX1)

# %% [markdown]
# Plot Y3

# %%
figY3 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, y3, label="y_3", color="red", linewidth=linewidth, linestyle="solid")

plt.title("Kết quả biến đổi Fourier tín hiệu trục Y cảm biến số 3", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureY1.png")
# plt.close(figY1)

# %% [markdown]
# Plot Z3

# %%
figZ3 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, z3, label="z_3", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("Kết quả biến đổi Fourier tín hiệu trục Z cảm biến số 3", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureZ1.png")
# plt.close(figZ1)

# %% [markdown]
# Plot Full All

# %%
fig = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x1, label="x_1", color="blue", linewidth=linewidth, linestyle="dashed")
plt.plot(t, y1, label="y_1", color="red", linewidth=linewidth, linestyle="dashed")
plt.plot(t, z1, label="z_1", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.plot(t, x2, label="x_2", color="blue", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, y2, label="y_2", color="red", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, z2, label="z_2", color="#00aa00ff", linewidth=linewidth, linestyle="dashdot")

plt.plot(t, x3, label="x_3", color="blue", linewidth=linewidth, linestyle="solid")
plt.plot(t, y3, label="y_3", color="red", linewidth=linewidth, linestyle="solid")
plt.plot(t, z3, label="z_3", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("Kết quả biến đổi Fourier tín hiệu 3 cảm biến", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()
# plt.savefig("figure4.png")
# plt.close(fig4)
