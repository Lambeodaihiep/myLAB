# %% [markdown]
# Đọc dữ liệu

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import text
import gspread
import numpy as np

plt.rcParams["savefig.directory"] = "C:/Downloads/"

sa = gspread.service_account(filename="A:\Code\Google_sheet\healthy-feat-390910-729c14c55127.json")
sh = sa.open("Dữ liệu rung Delta lần 22.1") # tên sheet muốn sử dụng, đổi mỗi lần muốn đọc dữ liệu ở sheet khác

wks = sh.worksheet("2. Động cơ quay với vi bước 1/32 - ko lọc") # tên worksheet muốn sử dụng, cái này mặc định rồi đừng có mà đổi
data = wks.get('A3:J')

t = []

x1 = []
y1 = []
z1 = []

x2 = []
y2 = []
z2 = []

x3 = []
y3 = []
z3 = []

# Number of sample points
N = len(data)

for i in range(0, N):
    t.append(float(data[i][0]))

    x1.append(float(data[i][1]))
    y1.append(float(data[i][2]))
    z1.append(float(data[i][3]))

    x2.append(float(data[i][4]))
    y2.append(float(data[i][5]))
    z2.append(float(data[i][6]))

    x3.append(float(data[i][7]))
    y3.append(float(data[i][8]))
    z3.append(float(data[i][9]))
# for i in range(0, len(read)):
#     if read[i] == "\t\t\t\t\t\t\t\t\t\n":
#         break
#     else:
#         listRead = read[i].split("\t")
#         t.append(float(listRead[0]))
#         x1.append(float(listRead[1])-79+240)
#         y1.append(float(listRead[2])-49+210)
#         z1.append(float(listRead[3])-25+190)
#         x2.append(float(listRead[4])-85+150)
#         y2.append(float(listRead[5])-63+120)
#         z2.append(float(listRead[6])-37+100)
#         x3.append(float(listRead[7])-95+60)
#         y3.append(float(listRead[8])-70+40)
#         z3.append(float(listRead[9])-46+20)

# %% [markdown]
# Cài đặt thông số

# %%
linewidth = 2
fontsize = 28

x_min = 0
x_max = 35000
y_min = 0
y_max = 160
yt_max = 120

t0 = 0
t1 = t[-1] * 1000 / N
t2 = t[-1] * 2000 / N
t3 = t[-1] * 3000 / N
t4 = t[-1]

xt0 = np.array([t1, t1])
xt1 = np.array([t2, t2])
xt2 = np.array([t3, t3])
xt3 = np.array([t4, t4])
yt = np.array([y_min, y_max])

# %% [markdown]
# Plot Full1

# %%
fig1 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x1, label="x_1", color="blue", linewidth=linewidth, linestyle="dashed")
plt.plot(t, y1, label="y_1", color="red", linewidth=linewidth, linestyle="dashed")
plt.plot(t, z1, label="z_1", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.plot(xt0, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt1, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt2, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt3, yt, linewidth = linewidth, c = 'orange') 

plt.arrow(t0 + (t1 - t0) / 2, yt_max, (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t0 + (t1 - t0) / 2, yt_max, - (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t0 + (t1 - t0) / 2, yt_max + 1, 'T0', fontsize = 22)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, - (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t1 + (t2 - t1) / 2, yt_max + 1, 'T1', fontsize = 22)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, - (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t2 + (t3 - t2) / 2, yt_max + 1, 'T2', fontsize = 22)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, - (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t3 + (t4 - t3) / 2, yt_max + 1, 'T3', fontsize = 22)

plt.annotate(text='', xy=(10000,10000), xytext=(0,0), arrowprops=dict(arrowstyle='<->'))

plt.title("Tín hiệu cảm biến số 1", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (ms)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figure1.png")
# plt.close(fig1)

# %% [markdown]
# Plot X1

# %%
figX1 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x1, label="x_1", color="blue", linewidth=linewidth, linestyle="dashed")

plt.title("Tín hiệu trục X cảm biến số 1", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.plot(xt0, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt1, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt2, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt3, yt, linewidth = linewidth, c = 'orange') 

plt.arrow(t0 + (t1 - t0) / 2, yt_max, (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t0 + (t1 - t0) / 2, yt_max, - (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t0 + (t1 - t0) / 2, yt_max + 1, 'T0', fontsize = 22)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, - (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t1 + (t2 - t1) / 2, yt_max + 1, 'T1', fontsize = 22)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, - (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t2 + (t3 - t2) / 2, yt_max + 1, 'T2', fontsize = 22)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, - (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t3 + (t4 - t3) / 2, yt_max + 1, 'T3', fontsize = 22)

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureX1.png")
# plt.close(figX1)

# %% [markdown]
# Plot Y1

# %%
figY1 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, y1, label="y_1", color="red", linewidth=linewidth, linestyle="dashed")

plt.title("Tín hiệu trục Y cảm biến số 1", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.plot(xt0, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt1, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt2, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt3, yt, linewidth = linewidth, c = 'orange') 

plt.arrow(t0 + (t1 - t0) / 2, yt_max, (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t0 + (t1 - t0) / 2, yt_max, - (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t0 + (t1 - t0) / 2, yt_max + 1, 'T0', fontsize = 22)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, - (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t1 + (t2 - t1) / 2, yt_max + 1, 'T1', fontsize = 22)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, - (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t2 + (t3 - t2) / 2, yt_max + 1, 'T2', fontsize = 22)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, - (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t3 + (t4 - t3) / 2, yt_max + 1, 'T3', fontsize = 22)

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureY1.png")
# plt.close(figY1)

# %% [markdown]
# Plot Z1

# %%
figZ1 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, z1, label="z_1", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.title("Tín hiệu trục Z cảm biến số 1", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.plot(xt0, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt1, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt2, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt3, yt, linewidth = linewidth, c = 'orange') 

plt.arrow(t0 + (t1 - t0) / 2, yt_max, (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t0 + (t1 - t0) / 2, yt_max, - (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t0 + (t1 - t0) / 2, yt_max + 1, 'T0', fontsize = 22)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, - (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t1 + (t2 - t1) / 2, yt_max + 1, 'T1', fontsize = 22)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, - (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t2 + (t3 - t2) / 2, yt_max + 1, 'T2', fontsize = 22)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, - (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t3 + (t4 - t3) / 2, yt_max + 1, 'T3', fontsize = 22)

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureZ1.png")
# plt.close(figZ1)

# %% [markdown]
# Plot Full2

# %%
fig2 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x2, label="x_2", color="blue", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, y2, label="y_2", color="red", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, z2, label="z_2", color="#00aa00ff", linewidth=linewidth, linestyle="dashdot")

plt.title("Tín hiệu cảm biến số 2", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.plot(xt0, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt1, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt2, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt3, yt, linewidth = linewidth, c = 'orange') 

plt.arrow(t0 + (t1 - t0) / 2, yt_max, (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t0 + (t1 - t0) / 2, yt_max, - (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t0 + (t1 - t0) / 2, yt_max + 1, 'T0', fontsize = 22)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, - (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t1 + (t2 - t1) / 2, yt_max + 1, 'T1', fontsize = 22)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, - (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t2 + (t3 - t2) / 2, yt_max + 1, 'T2', fontsize = 22)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, - (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t3 + (t4 - t3) / 2, yt_max + 1, 'T3', fontsize = 22)

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figure2.png")
# plt.close(fig2)

# %% [markdown]
# Plot X2

# %%
figX2 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x2, label="x_2", color="blue", linewidth=linewidth, linestyle="dashdot")

plt.title("Tín hiệu trục X cảm biến số 2", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.plot(xt0, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt1, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt2, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt3, yt, linewidth = linewidth, c = 'orange') 

plt.arrow(t0 + (t1 - t0) / 2, yt_max, (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t0 + (t1 - t0) / 2, yt_max, - (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t0 + (t1 - t0) / 2, yt_max + 1, 'T0', fontsize = 22)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, - (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t1 + (t2 - t1) / 2, yt_max + 1, 'T1', fontsize = 22)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, - (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t2 + (t3 - t2) / 2, yt_max + 1, 'T2', fontsize = 22)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, - (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t3 + (t4 - t3) / 2, yt_max + 1, 'T3', fontsize = 22)

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureX1.png")
# plt.close(figX1)

# %% [markdown]
# Plot Y2

# %%
figY2 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, y2, label="y_2", color="red", linewidth=linewidth, linestyle="dashdot")

plt.title("Tín hiệu trục Y cảm biến số 2", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.plot(xt0, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt1, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt2, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt3, yt, linewidth = linewidth, c = 'orange') 

plt.arrow(t0 + (t1 - t0) / 2, yt_max, (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t0 + (t1 - t0) / 2, yt_max, - (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t0 + (t1 - t0) / 2, yt_max + 1, 'T0', fontsize = 22)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, - (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t1 + (t2 - t1) / 2, yt_max + 1, 'T1', fontsize = 22)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, - (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t2 + (t3 - t2) / 2, yt_max + 1, 'T2', fontsize = 22)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, - (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t3 + (t4 - t3) / 2, yt_max + 1, 'T3', fontsize = 22)

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureY1.png")
# plt.close(figY1)

# %% [markdown]
# Plot Z2

# %%
figZ2 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, z2, label="z_2", color="#00aa00ff", linewidth=linewidth, linestyle="dashdot")

plt.title("Tín hiệu trục Z cảm biến số 2", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.plot(xt0, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt1, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt2, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt3, yt, linewidth = linewidth, c = 'orange') 

plt.arrow(t0 + (t1 - t0) / 2, yt_max, (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t0 + (t1 - t0) / 2, yt_max, - (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t0 + (t1 - t0) / 2, yt_max + 1, 'T0', fontsize = 22)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, - (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t1 + (t2 - t1) / 2, yt_max + 1, 'T1', fontsize = 22)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, - (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t2 + (t3 - t2) / 2, yt_max + 1, 'T2', fontsize = 22)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, - (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t3 + (t4 - t3) / 2, yt_max + 1, 'T3', fontsize = 22)

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureZ1.png")
# plt.close(figZ1)

# %% [markdown]
# Plot Full3

# %%
fig3 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x3, label="x_3", color="blue", linewidth=linewidth, linestyle="solid")
plt.plot(t, y3, label="y_3", color="red", linewidth=linewidth, linestyle="solid")
plt.plot(t, z3, label="z_3", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("Tín hiệu cảm biến số 3", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.plot(xt0, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt1, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt2, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt3, yt, linewidth = linewidth, c = 'orange') 

plt.arrow(t0 + (t1 - t0) / 2, yt_max, (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t0 + (t1 - t0) / 2, yt_max, - (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t0 + (t1 - t0) / 2, yt_max + 1, 'T0', fontsize = 22)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, - (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t1 + (t2 - t1) / 2, yt_max + 1, 'T1', fontsize = 22)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, - (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t2 + (t3 - t2) / 2, yt_max + 1, 'T2', fontsize = 22)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, - (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t3 + (t4 - t3) / 2, yt_max + 1, 'T3', fontsize = 22)

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figure3.png")
# plt.close(fig3)

# %% [markdown]
# Plot X3

# %%
figX3 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x3, label="x_3", color="blue", linewidth=linewidth, linestyle="solid")

plt.title("Tín hiệu trục X cảm biến số 3", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.plot(xt0, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt1, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt2, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt3, yt, linewidth = linewidth, c = 'orange') 

plt.arrow(t0 + (t1 - t0) / 2, yt_max, (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t0 + (t1 - t0) / 2, yt_max, - (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t0 + (t1 - t0) / 2, yt_max + 1, 'T0', fontsize = 22)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, - (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t1 + (t2 - t1) / 2, yt_max + 1, 'T1', fontsize = 22)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, - (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t2 + (t3 - t2) / 2, yt_max + 1, 'T2', fontsize = 22)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, - (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t3 + (t4 - t3) / 2, yt_max + 1, 'T3', fontsize = 22)

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureX1.png")
# plt.close(figX1)

# %% [markdown]
# Plot Y3

# %%
figY3 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, y3, label="y_3", color="red", linewidth=linewidth, linestyle="solid")

plt.title("Tín hiệu trục Y cảm biến số 3", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.plot(xt0, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt1, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt2, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt3, yt, linewidth = linewidth, c = 'orange') 

plt.arrow(t0 + (t1 - t0) / 2, yt_max, (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t0 + (t1 - t0) / 2, yt_max, - (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t0 + (t1 - t0) / 2, yt_max + 1, 'T0', fontsize = 22)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, - (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t1 + (t2 - t1) / 2, yt_max + 1, 'T1', fontsize = 22)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, - (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t2 + (t3 - t2) / 2, yt_max + 1, 'T2', fontsize = 22)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, - (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t3 + (t4 - t3) / 2, yt_max + 1, 'T3', fontsize = 22)

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureY1.png")
# plt.close(figY1)

# %% [markdown]
# Plot Z3

# %%
figZ3 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, z3, label="z_3", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("Tín hiệu trục Z cảm biến số 3", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.plot(xt0, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt1, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt2, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt3, yt, linewidth = linewidth, c = 'orange') 

plt.arrow(t0 + (t1 - t0) / 2, yt_max, (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t0 + (t1 - t0) / 2, yt_max, - (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t0 + (t1 - t0) / 2, yt_max + 1, 'T0', fontsize = 22)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, - (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t1 + (t2 - t1) / 2, yt_max + 1, 'T1', fontsize = 22)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, - (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t2 + (t3 - t2) / 2, yt_max + 1, 'T2', fontsize = 22)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, - (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t3 + (t4 - t3) / 2, yt_max + 1, 'T3', fontsize = 22)

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()

# plt.savefig("figureZ1.png")
# plt.close(figZ1)

# %% [markdown]
# Plot Full All

# %%
fig = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x1, label="x_1", color="blue", linewidth=linewidth, linestyle="dashed")
plt.plot(t, y1, label="y_1", color="red", linewidth=linewidth, linestyle="dashed")
plt.plot(t, z1, label="z_1", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.plot(t, x2, label="x_2", color="blue", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, y2, label="y_2", color="red", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, z2, label="z_2", color="#00aa00ff", linewidth=linewidth, linestyle="dashdot")

plt.plot(t, x3, label="x_3", color="blue", linewidth=linewidth, linestyle="solid")
plt.plot(t, y3, label="y_3", color="red", linewidth=linewidth, linestyle="solid")
plt.plot(t, z3, label="z_3", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("Tín hiệu 3 cảm biến", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.plot(xt0, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt1, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt2, yt, linewidth = linewidth, c = 'orange') 
plt.plot(xt3, yt, linewidth = linewidth, c = 'orange') 

plt.arrow(t0 + (t1 - t0) / 2, yt_max, (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t0 + (t1 - t0) / 2, yt_max, - (t1 - t0) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t0 + (t1 - t0) / 2, yt_max + 1, 'T0', fontsize = 22)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t1 + (t2 - t1) / 2, yt_max, - (t2 - t1) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t1 + (t2 - t1) / 2, yt_max + 1, 'T1', fontsize = 22)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t2 + (t3 - t2) / 2, yt_max, - (t3 - t2) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t2 + (t3 - t2) / 2, yt_max + 1, 'T2', fontsize = 22)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.arrow(t3 + (t4 - t3) / 2, yt_max, - (t4 - t3) / 2, 0, head_width=4, head_length=300, linewidth=linewidth, color='orange', length_includes_head=True)
plt.text(t3 + (t4 - t3) / 2, yt_max + 1, 'T3', fontsize = 22)

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
plt.show()
# plt.savefig("figure.png")
# plt.close(fig)
