# %% [markdown]
# plot FFT

# %%
import matplotlib.pyplot as plt

plt.rcParams["savefig.directory"] = "D:/Downloads/"
rf = open("D:\Documents\VS_Code\Python\OUTPUT_F.txt", "r")
read = rf.readlines()

# print(read)
# del read[0:0]

t = []
x1 = []
y1 = []
z1 = []
x2 = []
y2 = []
z2 = []
x3 = []
y3 = []
z3 = []

for i in range(0, len(read)):
    if read[i] == "\t\t\t\t\t\t\t\t\t\n":
        break
    else:
        listRead = read[i].split("\t")
        t.append(float(listRead[0]))
        x1.append(float(listRead[1]))
        y1.append(float(listRead[2]))
        z1.append(float(listRead[3]))
        x2.append(float(listRead[4]))
        y2.append(float(listRead[5]))
        z2.append(float(listRead[6]))
        x3.append(float(listRead[7]))
        y3.append(float(listRead[8]))
        z3.append(float(listRead[9]))

# Number of sample points
N = len(t)

linewidth = 2
fontsize = 28

x_min = 0
x_max = 10
y_min = 0
y_max = 3

# Plot figure 1
fig1 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x1, label="x", color="blue", linewidth=linewidth, linestyle="dashed")
plt.plot(t, y1, label="y", color="red", linewidth=linewidth, linestyle="dashed")
plt.plot(t, z1, label="z", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.title("Kết quả biến đổi Fourier tín hiệu cảm biến số 1", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()

# plt.savefig("figure1.png")
# plt.close(fig1)

# Plot figure 2
fig2 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x2, label="x", color="blue", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, y2, label="y", color="red", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, z2, label="z", color="#00aa00ff", linewidth=linewidth, linestyle="dashdot")

plt.title("Kết quả biến đổi Fourier tín hiệu cảm biến số 2", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
# plt.savefig("figure2.png")
# plt.close(fig2)

# Plot figure 3
fig3 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x3, label="x", color="blue", linewidth=linewidth, linestyle="solid")
plt.plot(t, y3, label="y", color="red", linewidth=linewidth, linestyle="solid")
plt.plot(t, z3, label="z", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("Kết quả biến đổi Fourier tín hiệu cảm biến số 3", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
# plt.savefig("figure3.png")
# plt.close(fig3)

# Plot figure 4
fig4 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x1, label="x_1", color="blue", linewidth=linewidth, linestyle="dashed")
plt.plot(t, y1, label="y_1", color="red", linewidth=linewidth, linestyle="dashed")
plt.plot(t, z1, label="z_1", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.plot(t, x2, label="x_2", color="blue", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, y2, label="y_2", color="red", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, z2, label="z_2", color="#00aa00ff", linewidth=linewidth, linestyle="dashdot")

plt.plot(t, x3, label="x_3", color="blue", linewidth=linewidth, linestyle="solid")
plt.plot(t, y3, label="y_3", color="red", linewidth=linewidth, linestyle="solid")
plt.plot(t, z3, label="z_3", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("Kết quả biến đổi Fourier tín hiệu 3 cảm biến", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
# plt.savefig("figure4.png")
# plt.close(fig4)


plt.show()
rf.close()

# %% [markdown]
# plot tín hiệu

# %%
import matplotlib.pyplot as plt

plt.rcParams["savefig.directory"] = "D:/Downloads/"
rf = open("D:\Documents\VS_Code\Python\INPUT_t.txt", "r")
read = rf.readlines()

# print(read)
del read[0:2]

t = []
x1 = []
y1 = []
z1 = []
x2 = []
y2 = []
z2 = []
x3 = []
y3 = []
z3 = []

for i in range(0, len(read)):
    if read[i] == "\t\t\t\t\t\t\t\t\t\n":
        break
    else:
        listRead = read[i].split("\t")
        t.append(float(listRead[0]))
        x1.append(float(listRead[1]))
        y1.append(float(listRead[2]))
        z1.append(float(listRead[3]))
        x2.append(float(listRead[4]))
        y2.append(float(listRead[5]))
        z2.append(float(listRead[6]))
        x3.append(float(listRead[7]))
        y3.append(float(listRead[8]))
        z3.append(float(listRead[9]))

# Number of sample points
N = len(t)

linewidth = 2
fontsize = 28

x_min = 0
x_max = 10
y_min = 0
y_max = 3

# Plot figure 1
fig1 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x1, label="x", color="blue", linewidth=linewidth, linestyle="dashed")
plt.plot(t, y1, label="y", color="red", linewidth=linewidth, linestyle="dashed")
plt.plot(t, z1, label="z", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.title("Tín hiệu cảm biến số 1", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()

# plt.savefig("figure1.png")
# plt.close(fig1)

# Plot figure 2
fig2 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x2, label="x", color="blue", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, y2, label="y", color="red", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, z2, label="z", color="#00aa00ff", linewidth=linewidth, linestyle="dashdot")

plt.title("Tín hiệu cảm biến số 2", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
# plt.savefig("figure2.png")
# plt.close(fig2)

# Plot figure 3
fig3 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x3, label="x", color="blue", linewidth=linewidth, linestyle="solid")
plt.plot(t, y3, label="y", color="red", linewidth=linewidth, linestyle="solid")
plt.plot(t, z3, label="z", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("Tín hiệu cảm biến số 3", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
# plt.savefig("figure3.png")
# plt.close(fig3)

# Plot figure 4
fig4 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x1, label="x_1", color="blue", linewidth=linewidth, linestyle="dashed")
plt.plot(t, y1, label="y_1", color="red", linewidth=linewidth, linestyle="dashed")
plt.plot(t, z1, label="z_1", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.plot(t, x2, label="x_2", color="blue", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, y2, label="y_2", color="red", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, z2, label="z_2", color="#00aa00ff", linewidth=linewidth, linestyle="dashdot")

plt.plot(t, x3, label="x_3", color="blue", linewidth=linewidth, linestyle="solid")
plt.plot(t, y3, label="y_3", color="red", linewidth=linewidth, linestyle="solid")
plt.plot(t, z3, label="z_3", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("Tín hiệu 3 cảm biến", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

# plt.xlim(x_min, x_max)
# plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
# plt.savefig("figure4.png")
# plt.close(fig4)



plt.show()
rf.close()

# %% [markdown]
# plot so sánh

# %%
import matplotlib.pyplot as plt

plt.rcParams["savefig.directory"] = "D:/Downloads/"
rf = open("D:\Documents\VS_Code\Python\INPUT_Plot.txt", "r")
read = rf.readlines()

# print(read)
del read[0:3]

t1 = []
x1 = []
y1 = []
z1 = []

t2 = []
x2 = []
y2 = []
z2 = []



for i in range(0, len(read)):
    if read[i] == "\t\t\t\t\t\t\t\n":
        break
    else:
        listRead = read[i].split("\t")
        t1.append(float(listRead[0]))
        x1.append(float(listRead[1]))
        y1.append(float(listRead[2]))
        z1.append(float(listRead[3]))

        t2.append(float(listRead[4]))
        x2.append(float(listRead[5]))
        y2.append(float(listRead[6]))
        z2.append(float(listRead[7]))
        

# Number of sample points
N = len(t1)

linewidth = 2
fontsize = 28

x_min = 0
x_max = 10
y_min = 0
y_max = 3

# Plot figure 1
fig1 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t1, x1, label="x", color="blue", linewidth=linewidth, linestyle="dashed")
plt.plot(t1, y1, label="y", color="red", linewidth=linewidth, linestyle="dashed")
plt.plot(t1, z1, label="z", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.title("Biến đổi Fourier tín hiệu cũ", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()

# plt.savefig("figure1.png")
# plt.close(fig1)

# Plot figure 2
fig2 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t2, x2, label="x", color="blue", linewidth=linewidth, linestyle="solid")
plt.plot(t2, y2, label="y", color="red", linewidth=linewidth, linestyle="solid")
plt.plot(t2, z2, label="z", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("Biến đổi Fourier tín hiệu mới", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
# plt.savefig("figure2.png")
# plt.close(fig2)


# Plot figure 3
fig3 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t1, x1, label="x_OLD", color="blue", linewidth=linewidth, linestyle="dashed")
plt.plot(t1, y1, label="y_OLD", color="red", linewidth=linewidth, linestyle="dashed")
plt.plot(t1, z1, label="z_OLD", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.plot(t2, x2, label="x_NEW", color="blue", linewidth=linewidth, linestyle="solid")
plt.plot(t2, y2, label="y_NEW", color="red", linewidth=linewidth, linestyle="solid")
plt.plot(t2, z2, label="z_NEW", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("So sánh biến đổi Fourier tín hiệu", fontsize=fontsize, weight="bold")
plt.xlabel("Tần số (Hz)", fontsize=fontsize, weight="bold")
plt.ylabel("Biên độ (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
# plt.savefig("figure3.png")
# plt.close(fig3)


plt.show()
rf.close()

# %% [markdown]
# Plot Homiing

# %%
import matplotlib.pyplot as plt

plt.rcParams["savefig.directory"] = "D:/Downloads/"
rf = open("D:\Documents\VS_Code\Python\INPUT_t.txt", "r")
read = rf.readlines()

# print(read)
del read[0:2]

t = []
x1 = []
y1 = []
z1 = []
x2 = []
y2 = []
z2 = []
x3 = []
y3 = []
z3 = []

for i in range(0, len(read)):
    if read[i] == "\t\t\t\t\t\t\t\t\t\n":
        break
    else:
        listRead = read[i].split("\t")
        t.append(float(listRead[0]))
        x1.append(float(listRead[1])-79+240)
        y1.append(float(listRead[2])-49+210)
        z1.append(float(listRead[3])-25+190)
        x2.append(float(listRead[4])-85+150)
        y2.append(float(listRead[5])-63+120)
        z2.append(float(listRead[6])-37+100)
        x3.append(float(listRead[7])-95+60)
        y3.append(float(listRead[8])-70+40)
        z3.append(float(listRead[9])-46+20)

# Number of sample points
N = len(t)

linewidth = 2
fontsize = 28

x_min = 0
x_max = 35500
y_min = 0
y_max = 350

# Plot figure 1
fig1 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x1, label="x", color="blue", linewidth=linewidth, linestyle="dashed")
plt.plot(t, y1, label="y", color="red", linewidth=linewidth, linestyle="dashed")
plt.plot(t, z1, label="z", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.title("Tín hiệu cảm biến số 1", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()

# plt.savefig("figure1.png")
# plt.close(fig1)

# Plot figure 2
fig2 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x2, label="x", color="blue", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, y2, label="y", color="red", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, z2, label="z", color="#00aa00ff", linewidth=linewidth, linestyle="dashdot")

plt.title("Tín hiệu cảm biến số 2", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
# plt.savefig("figure2.png")
# plt.close(fig2)

# Plot figure 3
fig3 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x3, label="x", color="blue", linewidth=linewidth, linestyle="solid")
plt.plot(t, y3, label="y", color="red", linewidth=linewidth, linestyle="solid")
plt.plot(t, z3, label="z", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("Tín hiệu cảm biến số 3", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
# plt.savefig("figure3.png")
# plt.close(fig3)

# Plot figure 4
fig4 = plt.figure(figsize=(16, 8), dpi=120)

plt.plot(t, x1, label="x_1", color="blue", linewidth=linewidth, linestyle="dashed")
plt.plot(t, y1, label="y_1", color="red", linewidth=linewidth, linestyle="dashed")
plt.plot(t, z1, label="z_1", color="#00aa00ff", linewidth=linewidth, linestyle="dashed")

plt.plot(t, x2, label="x_2", color="blue", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, y2, label="y_2", color="red", linewidth=linewidth, linestyle="dashdot")
plt.plot(t, z2, label="z_2", color="#00aa00ff", linewidth=linewidth, linestyle="dashdot")

plt.plot(t, x3, label="x_3", color="blue", linewidth=linewidth, linestyle="solid")
plt.plot(t, y3, label="y_3", color="red", linewidth=linewidth, linestyle="solid")
plt.plot(t, z3, label="z_3", color="#00aa00ff", linewidth=linewidth, linestyle="solid")

plt.title("Tín hiệu 3 cảm biến", fontsize=fontsize, weight="bold")
plt.xlabel("Thời gian (s)", fontsize=fontsize, weight="bold")
plt.ylabel("Tín hiệu (Analog)", fontsize=fontsize, weight="bold")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

plt.legend(fontsize=fontsize, loc="upper right")

plt.subplots_adjust(
    top=0.937, bottom=0.125, left=0.082, right=0.975, hspace=0.203, wspace=0.2
)

plt.grid()
# plt.savefig("figure4.png")
# plt.close(fig4)

plt.show()
rf.close()

# %% [markdown]
# END
